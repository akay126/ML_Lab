# %%
import pandas as pd
import numpy as np
import re
from decimal import Decimal
import matplotlib.pyplot as plt

# %%
orders = pd.read_csv("data/Orders.csv")
returns = pd.read_csv("data/Returns.csv")

# %%
orders['Sales'] = orders['Sales'].replace('[\$,]', '', regex=True).astype(float)
orders['Profit'] = orders['Profit'].replace('[\$,]', '', regex=True).astype(float)

# %%
orders.hist(bins= 40, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001850B44D400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001850B45CEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001850AF61CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001850B0DD940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001850B0E5320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001850B0274A8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001850B73D710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001850B701EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001850B701EF0>]],
#       dtype=object)

# %%
orders.groupby('Order.Date')['Sales'].sum()
# Out:
# Order.Date
# 1/1/12       808.57
# 1/1/13     10006.66
# 1/1/14      9369.15
# 1/1/15      3614.05
# 1/10/12     6794.19
# 1/10/13     8259.47
# 1/10/14     7617.95
# 1/10/15     4202.12
# 1/11/12     6451.25
# 1/11/13     8385.12
# 1/11/14     4942.56
# 1/11/15     4428.56
# 1/12/12     2629.71
# 1/12/13     7106.17
# 1/12/14     7543.69
# 1/12/15       74.38
# 1/13/12     2584.60
# 1/13/13     2041.02
# 1/13/14       46.12
# 1/13/15     5358.29
# 1/14/12     6280.45
# 1/14/14     2583.11
# 1/14/15    17297.79
# 1/15/12     2279.53
# 1/15/13     8370.40
# 1/15/14     7600.40
# 1/15/15     6001.59
# 1/16/12      149.95
# 1/16/13     6562.92
# 1/16/14     4987.94
#              ...
# 9/3/14     22431.61
# 9/3/15     27844.22
# 9/30/12     1624.21
# 9/30/13      668.95
# 9/30/14    16996.51
# 9/30/15    13452.25
# 9/4/12      4149.87
# 9/4/13     10733.87
# 9/4/14     14181.09
# 9/4/15     19503.08
# 9/5/12     10296.68
# 9/5/13      9362.83
# 9/5/14     17986.44
# 9/5/15     19645.24
# 9/6/12      6333.66
# 9/6/13     15371.88
# 9/6/14     14405.46
# 9/6/15     12910.18
# 9/7/12     36827.76
# 9/7/13     13642.54
# 9/7/14      2432.22
# 9/7/15       630.36
# 9/8/12     11577.05
# 9/8/13      2772.00
# 9/8/14      1058.21
# 9/8/15     27668.93
# 9/9/12      3268.43
# 9/9/13      3305.82
# 9/9/14     15472.05
# 9/9/15     10259.96
# Name: Sales, Length: 1430, dtype: float64
